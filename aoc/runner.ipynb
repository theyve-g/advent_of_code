# %%
cd six
# Out:
# /Users/dev/Development/advent_of_code/aoc/six

# %%
import six

# %%
f = open("input_one.txt")

# %%
text = f.read()

# %%
six.main(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 six.main(text)
#
# AttributeError: module 'six' has no attribute 'main'
